# %%
import os

# Read API key from file using full path
with open("/Users/kpitsiakkos/Desktop/CERTIFICATES/Langchain and Langgraph Specialization/openai_token.txt", "r") as f:
    api_key = f.read().strip()

os.environ["OPENAI_API_KEY"] = api_key

# %%
# !pip install langchain
# Out:
# Collecting langchain
#   Using cached langchain-1.2.13-py3-none-any.whl (112 kB)
# Collecting langgraph<1.2.0,>=1.1.1
#   Using cached langgraph-1.1.3-py3-none-any.whl (168 kB)
# Collecting langchain-core<2.0.0,>=1.2.10
#   Using cached langchain_core-1.2.22-py3-none-any.whl (506 kB)
# Collecting pydantic<3.0.0,>=2.7.4
#   Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0
#   Using cached tenacity-9.1.4-py3-none-any.whl (28 kB)
# Requirement already satisfied: packaging>=23.2.0 in ./.venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (26.0)
# Collecting jsonpatch<2.0.0,>=1.33.0
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in ./.venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Collecting pyyaml<7.0.0,>=5.3.0
#   Using cached pyyaml-6.0.3-cp310-cp310-macosx_10_13_x86_64.whl (184 kB)
# Collecting langsmith<1.0.0,>=0.3.45
#   Using cached langsmith-0.7.22-py3-none-any.whl (359 kB)
# Collecting uuid-utils<1.0,>=0.12.0
#   Using cached uuid_utils-0.14.1-cp39-abi3-macosx_10_12_x86_64.whl (309 kB)
# Collecting jsonpointer>=1.9
#   Using cached jsonpointer-3.1.1-py3-none-any.whl (7.7 kB)
# Collecting langgraph-checkpoint<5.0.0,>=2.1.0
#   Using cached langgraph_checkpoint-4.0.1-py3-none-any.whl (50 kB)
# Collecting xxhash>=3.5.0
#   Using cached xxhash-3.6.0-cp310-cp310-macosx_10_9_x86_64.whl (32 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.8
#   Using cached langgraph_prebuilt-1.0.8-py3-none-any.whl (35 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0
#   Using cached langgraph_sdk-0.3.12-py3-none-any.whl (95 kB)
# Collecting ormsgpack>=1.12.0
#   Using cached ormsgpack-1.12.2-cp310-cp310-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (378 kB)
# Collecting orjson>=3.11.5
#   Using cached orjson-3.11.7-cp310-cp310-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (229 kB)
# Collecting httpx>=0.25.2
#   Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Collecting idna
#   Using cached idna-3.11-py3-none-any.whl (71 kB)
# Collecting httpcore==1.*
#   Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Collecting certifi
#   Using cached certifi-2026.2.25-py3-none-any.whl (153 kB)
# Collecting anyio
#   Using cached anyio-4.13.0-py3-none-any.whl (114 kB)
# Collecting h11>=0.16
#   Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Collecting zstandard>=0.23.0
#   Using cached zstandard-0.25.0-cp310-cp310-macosx_10_9_x86_64.whl (795 kB)
# Collecting requests-toolbelt>=1.0.0
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Collecting requests>=2.0.0
#   Using cached requests-2.33.0-py3-none-any.whl (65 kB)
# Collecting annotated-types>=0.6.0
#   Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting typing-inspection>=0.4.2
#   Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Collecting pydantic-core==2.41.5
#   Using cached pydantic_core-2.41.5-cp310-cp310-macosx_10_12_x86_64.whl (2.1 MB)
# Collecting urllib3<3,>=1.26
#   Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Collecting charset_normalizer<4,>=2
#   Using cached charset_normalizer-3.4.6-cp310-cp310-macosx_10_9_universal2.whl (298 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.10/site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (1.3.1)
# Installing collected packages: urllib3, idna, h11, charset-normalizer, certifi, typing-inspection, requests, pydantic-core, httpcore, anyio, annotated-types, zstandard, xxhash, uuid-utils, requests-toolbelt, pydantic, orjson, jsonpointer, httpx, tenacity, pyyaml, langsmith, jsonpatch, ormsgpack, langchain-core, langgraph-checkpoint, langgraph-sdk, langgraph-prebuilt, langgraph, langchain
# Successfully installed annotated-types-0.7.0 anyio-4.13.0 certifi-2026.2.25 charset-normalizer-3.4.6 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.11 jsonpatch-1.33 jsonpointer-3.1.1 langchain-1.2.13 langchain-core-1.2.22 langgraph-1.1.3 langgraph-checkpoint-4.0.1 langgraph-prebuilt-1.0.8 langgraph-sdk-0.3.12 langsmith-0.7.22 orjson-3.11.7 ormsgpack-1.12.2 pydantic-2.12.5 pydantic-core-2.41.5 pyyaml-6.0.3 requests-2.33.0 requests-toolbelt-1.0.0 tenacity-9.1.4 typing-inspection-0.4.2 urllib3-2.6.3 uuid-utils-0.14.1 xxhash-3.6.0 zstandard-0.25.0
# WARNING: You are using pip version 21.2.3; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/kpitsiakkos/Documents/Langchain-and-Langgraph-Specialization/.venv/bin/python3 -m pip install --upgrade pip' command.

# %%
# !pip install langchain_openai
# Out:
# Collecting langchain_openai
#   Using cached langchain_openai-1.1.12-py3-none-any.whl (88 kB)
# Collecting openai<3.0.0,>=2.26.0
#   Using cached openai-2.30.0-py3-none-any.whl (1.1 MB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.21 in ./.venv/lib/python3.10/site-packages (from langchain_openai) (1.2.22)
# Collecting tiktoken<1.0.0,>=0.7.0
#   Using cached tiktoken-0.12.0-cp310-cp310-macosx_10_12_x86_64.whl (1.1 MB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./.venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_openai) (2.12.5)
# Requirement already satisfied: packaging>=23.2.0 in ./.venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_openai) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in ./.venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_openai) (6.0.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in ./.venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_openai) (4.15.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in ./.venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_openai) (0.7.22)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in ./.venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_openai) (1.33)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./.venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_openai) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in ./.venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.21->langchain_openai) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in ./.venv/lib/python3.10/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.21->langchain_openai) (3.1.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in ./.venv/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_openai) (1.0.0)
# Requirement already satisfied: orjson>=3.9.14 in ./.venv/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_openai) (3.11.7)
# Requirement already satisfied: xxhash>=3.0.0 in ./.venv/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_openai) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in ./.venv/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_openai) (0.25.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./.venv/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_openai) (0.28.1)
# Requirement already satisfied: requests>=2.0.0 in ./.venv/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_openai) (2.33.0)
# Requirement already satisfied: anyio in ./.venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_openai) (4.13.0)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_openai) (1.0.9)
# Requirement already satisfied: idna in ./.venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_openai) (3.11)
# Requirement already satisfied: certifi in ./.venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_openai) (2026.2.25)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_openai) (0.16.0)
# Collecting tqdm>4
#   Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Collecting distro<2,>=1.7.0
#   Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting sniffio
#   Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting jiter<1,>=0.10.0
#   Using cached jiter-0.13.0-cp310-cp310-macosx_10_12_x86_64.whl (311 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_openai) (1.3.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain_openai) (0.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain_openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain_openai) (2.41.5)
# Requirement already satisfied: urllib3<3,>=1.26 in ./.venv/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_openai) (2.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain_openai) (3.4.6)
# Collecting regex>=2022.1.18
#   Using cached regex-2026.2.28-cp310-cp310-macosx_10_9_x86_64.whl (290 kB)
# Installing collected packages: tqdm, sniffio, regex, jiter, distro, tiktoken, openai, langchain-openai
# Successfully installed distro-1.9.0 jiter-0.13.0 langchain-openai-1.1.12 openai-2.30.0 regex-2026.2.28 sniffio-1.3.1 tiktoken-0.12.0 tqdm-4.67.3
# WARNING: You are using pip version 21.2.3; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/kpitsiakkos/Documents/Langchain-and-Langgraph-Specialization/.venv/bin/python3 -m pip install --upgrade pip' command.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage

# %%
chat = ChatOpenAI(temperature=.7, model='gpt-3.5-turbo')

# %%
chat.invoke(
    [
        SystemMessage(content="You are a sarcastic AI assistant"),
        HumanMessage(content="Please answer in 30 words: How can I learn driving a car")
    ]
)
# Out:
# AIMessage(content='Oh, just hop in a car, close your eyes, and hope for the best! Or, you know, take driving lessons from a qualified instructor. Your call.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 34, 'prompt_tokens': 32, 'total_tokens': 66, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DNzfZWEmkkwlxXkuRJCDii6Vr2OpJ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d2f0e-7efd-74d1-b7b5-ba37a4a54d66-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 32, 'output_tokens': 34, 'total_tokens': 66, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
