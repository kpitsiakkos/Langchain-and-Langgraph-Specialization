# %%
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 11.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 458.9/458.9 KB 7.2 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 25.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.4/184.4 KB 5.7 MB/s eta 0:00:00
# ...
#   Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 463.6/463.6 KB 13.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 396.1/396.1 KB 11.0 MB/s eta 0:00:00
# ...
#   Using cached packaging-25.0-py3-none-any.whl (66 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.3/309.3 KB 7.1 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 795.3/795.3 KB 10.2 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.3/245.3 KB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 1.7 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain-openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 KB 1.6 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 16.6 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 22.1 MB/s eta 0:00:0000:01
# ...
#   Using cached langchain_core-0.3.83-py3-none-any.whl (458 kB)
# ...
#   Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# ...
#   Using cached pyyaml-6.0.3-cp39-cp39-macosx_10_13_x86_64.whl (184 kB)
# ...
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# ...
#   Using cached uuid_utils-0.14.1-cp39-abi3-macosx_10_12_x86_64.whl (309 kB)
# ...
#   Using cached packaging-25.0-py3-none-any.whl (66 kB)
# ...
#   Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# ...
#   Using cached langsmith-0.4.37-py3-none-any.whl (396 kB)
# ...
#   Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 KB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 KB 11.7 MB/s eta 0:00:00
# ...

# %%
# !pip install openai
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/kpitsiakkos/Desktop/certificates/Langchain and Langgraph Specialization/venv/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install PyPDF
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 333.7/333.7 KB 4.6 MB/s eta 0:00:0000:01
# ...
# WARNING: You are using pip version 22.0.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/kpitsiakkos/Desktop/certificates/Langchain and Langgraph Specialization/venv/bin/python -m pip install --upgrade pip' command.
