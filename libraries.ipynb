# %%
# !pip install langchain
# Out:
# Collecting langchain
#   Using cached langchain-0.3.28-py3-none-any.whl (1.0 MB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.73 in ./venv/lib/python3.9/site-packages (from langchain) (0.3.83)
# Collecting SQLAlchemy<3.0.0,>=1.4.0
#   Using cached sqlalchemy-2.0.48-py3-none-any.whl (1.9 MB)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in ./venv/lib/python3.9/site-packages (from langchain) (2.32.5)
# Collecting langchain-text-splitters<1.0.0,>=0.3.9
#   Using cached langchain_text_splitters-0.3.11-py3-none-any.whl (33 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./venv/lib/python3.9/site-packages (from langchain) (2.12.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in ./venv/lib/python3.9/site-packages (from langchain) (6.0.3)
# Collecting async-timeout<5.0.0,>=4.0.0
#   Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.17 in ./venv/lib/python3.9/site-packages (from langchain) (0.4.37)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in ./venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.73->langchain) (1.33)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.73->langchain) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in ./venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.73->langchain) (0.14.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in ./venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.73->langchain) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in ./venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.73->langchain) (25.0)
# Requirement already satisfied: zstandard>=0.23.0 in ./venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.1.17->langchain) (0.25.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in ./venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: orjson>=3.9.14 in ./venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.1.17->langchain) (3.11.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->langchain) (2.6.3)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->langchain) (3.11)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->langchain) (3.4.6)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->langchain) (2026.2.25)
# Collecting greenlet>=1
#   Using cached greenlet-3.2.5.tar.gz (191 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: anyio in ./venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain) (4.12.1)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./venv/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./venv/lib/python3.9/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.73->langchain) (3.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./venv/lib/python3.9/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain) (1.3.1)
# Building wheels for collected packages: greenlet
#   Building wheel for greenlet (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for greenlet (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [118 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       creating build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/platform/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       creating build/lib.macosx-10.9-x86_64-cpython-39/greenlet/tests
#       copying src/greenlet/tests/test_version.py -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/tests
#       copying src/greenlet/tests/test_weakref.py -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/tests
#       copying src/greenlet/tests/fail_slp_switch.py -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/tests
#       copying src/greenlet/tests/test_gc.py -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/tests
#       copying src/greenlet/tests/leakcheck.py -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/tests
#       copying src/greenlet/tests/fail_switch_two_greenlets.py -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/tests
#       copying src/greenlet/tests/test_generator.py -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/tests
#       copying src/greenlet/tests/test_greenlet_trash.py -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/tests
#       copying src/greenlet/tests/test_throw.py -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/tests
#       copying src/greenlet/tests/test_tracing.py -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/tests
#       copying src/greenlet/tests/fail_cpp_exception.py -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/tests
#       copying src/greenlet/tests/fail_switch_three_greenlets.py -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/tests
#       copying src/greenlet/tests/test_cpp.py -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/tests
#       copying src/greenlet/tests/test_contextvars.py -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/tests
#       copying src/greenlet/tests/test_greenlet.py -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/tests
#       copying src/greenlet/tests/test_extension_interface.py -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/tests
#       copying src/greenlet/tests/fail_clearing_run_switches.py -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/tests
#       copying src/greenlet/tests/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/tests
#       copying src/greenlet/tests/fail_switch_three_greenlets2.py -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/tests
#       copying src/greenlet/tests/test_interpreter_shutdown.py -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/tests
#       copying src/greenlet/tests/fail_initialstub_already_started.py -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/tests
#       copying src/greenlet/tests/test_generator_nested.py -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/tests
#       copying src/greenlet/tests/test_stack_saved.py -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/tests
#       copying src/greenlet/tests/test_leaks.py -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/tests
#       running egg_info
#       writing src/greenlet.egg-info/PKG-INFO
#       writing dependency_links to src/greenlet.egg-info/dependency_links.txt
#       writing requirements to src/greenlet.egg-info/requires.txt
#       writing top-level names to src/greenlet.egg-info/top_level.txt
#       reading manifest file 'src/greenlet.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no previously-included files found matching 'benchmarks/*.json'
#       no previously-included directories found matching 'docs/_build'
#       warning: no files found matching '*.py' under directory 'appveyor'
#       warning: no previously-included files matching '*.pyc' found anywhere in distribution
#       warning: no previously-included files matching '*.pyd' found anywhere in distribution
#       warning: no previously-included files matching '*.so' found anywhere in distribution
#       warning: no previously-included files matching '.coverage' found anywhere in distribution
#       adding license file 'LICENSE'
#       adding license file 'LICENSE.PSF'
#       writing manifest file 'src/greenlet.egg-info/SOURCES.txt'
#       copying src/greenlet/CObjects.cpp -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/PyGreenlet.cpp -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/PyGreenlet.hpp -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/PyGreenletUnswitchable.cpp -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/PyModule.cpp -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/TBrokenGreenlet.cpp -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/TExceptionState.cpp -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/TGreenlet.cpp -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/TGreenlet.hpp -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/TGreenletGlobals.cpp -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/TMainGreenlet.cpp -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/TPythonState.cpp -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/TStackState.cpp -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/TThreadState.hpp -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/TThreadStateCreator.hpp -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/TThreadStateDestroy.cpp -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/TUserGreenlet.cpp -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/greenlet.cpp -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/greenlet.h -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/greenlet_allocator.hpp -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/greenlet_compiler_compat.hpp -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/greenlet_cpython_compat.hpp -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/greenlet_exceptions.hpp -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/greenlet_internal.hpp -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/greenlet_msvc_compat.hpp -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/greenlet_refs.hpp -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/greenlet_slp_switch.hpp -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/greenlet_thread_support.hpp -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/slp_platformselect.h -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet
#       copying src/greenlet/platform/setup_switch_x64_masm.cmd -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/platform/switch_aarch64_gcc.h -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/platform/switch_alpha_unix.h -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/platform/switch_amd64_unix.h -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/platform/switch_arm32_gcc.h -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/platform/switch_arm32_ios.h -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/platform/switch_arm64_masm.asm -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/platform/switch_arm64_masm.obj -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/platform/switch_arm64_msvc.h -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/platform/switch_csky_gcc.h -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/platform/switch_loongarch64_linux.h -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/platform/switch_m68k_gcc.h -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/platform/switch_mips_unix.h -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/platform/switch_ppc64_aix.h -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/platform/switch_ppc64_linux.h -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/platform/switch_ppc_aix.h -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/platform/switch_ppc_linux.h -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/platform/switch_ppc_macosx.h -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/platform/switch_ppc_unix.h -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/platform/switch_riscv_unix.h -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/platform/switch_s390_unix.h -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/platform/switch_sh_gcc.h -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/platform/switch_sparc_sun_gcc.h -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/platform/switch_x32_unix.h -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/platform/switch_x64_masm.asm -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/platform/switch_x64_masm.obj -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/platform/switch_x64_msvc.h -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/platform/switch_x86_msvc.h -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/platform/switch_x86_unix.h -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/platform
#       copying src/greenlet/tests/_test_extension.c -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/tests
#       copying src/greenlet/tests/_test_extension_cpp.cpp -> build/lib.macosx-10.9-x86_64-cpython-39/greenlet/tests
#       running build_ext
#       building 'greenlet._greenlet' extension
#       creating build/temp.macosx-10.9-x86_64-cpython-39/src/greenlet
#       clang++ -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/kpitsiakkos/opt/anaconda3/include -arch x86_64 -I/Users/kpitsiakkos/opt/anaconda3/include -fPIC -O2 -isystem /Users/kpitsiakkos/opt/anaconda3/include -arch x86_64 "-I/Users/kpitsiakkos/Desktop/certificates/Langchain and Langgraph Specialization/venv/include" -I/Users/kpitsiakkos/opt/anaconda3/include/python3.9 -c src/greenlet/greenlet.cpp -o build/temp.macosx-10.9-x86_64-cpython-39/src/greenlet/greenlet.o --std=c++11
#       src/greenlet/greenlet.cpp:9:10: fatal error: 'cstdlib' file not found
#           9 | #include <cstdlib>
#             |          ^~~~~~~~~
#       1 error generated.
#       error: command '/usr/bin/clang++' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for greenlet
# Failed to build greenlet
# ERROR: Could not build wheels for greenlet, which is required to install pyproject.toml-based projects
# WARNING: You are using pip version 22.0.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/kpitsiakkos/Desktop/certificates/Langchain and Langgraph Specialization/venv/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install langchain-openai
# Out:
# Requirement already satisfied: langchain-openai in ./venv/lib/python3.9/site-packages (0.3.35)
# Requirement already satisfied: openai<3.0.0,>=1.104.2 in ./venv/lib/python3.9/site-packages (from langchain-openai) (2.29.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in ./venv/lib/python3.9/site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.78 in ./venv/lib/python3.9/site-packages (from langchain-openai) (0.3.83)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (9.1.2)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in ./venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in ./venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (4.15.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in ./venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (1.33)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in ./venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.14.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in ./venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.4.37)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in ./venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (6.0.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (2.12.5)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./venv/lib/python3.9/site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in ./venv/lib/python3.9/site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (0.13.0)
# Requirement already satisfied: sniffio in ./venv/lib/python3.9/site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (1.3.1)
# Requirement already satisfied: distro<2,>=1.7.0 in ./venv/lib/python3.9/site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (1.9.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./venv/lib/python3.9/site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (4.12.1)
# Requirement already satisfied: tqdm>4 in ./venv/lib/python3.9/site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (4.67.3)
# Requirement already satisfied: regex>=2022.1.18 in ./venv/lib/python3.9/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.1.15)
# Requirement already satisfied: requests>=2.26.0 in ./venv/lib/python3.9/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.32.5)
# Requirement already satisfied: idna>=2.8 in ./venv/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=1.104.2->langchain-openai) (3.11)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./venv/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=1.104.2->langchain-openai) (1.3.1)
# Requirement already satisfied: certifi in ./venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=1.104.2->langchain-openai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=1.104.2->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./venv/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<3.0.0,>=1.104.2->langchain-openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./venv/lib/python3.9/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.78->langchain-openai) (3.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in ./venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.25.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in ./venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (1.0.0)
# Requirement already satisfied: orjson>=3.9.14 in ./venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (3.11.5)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.78->langchain-openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (3.4.6)
# WARNING: You are using pip version 22.0.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/kpitsiakkos/Desktop/certificates/Langchain and Langgraph Specialization/venv/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in ./venv/lib/python3.9/site-packages (2.29.0)
# Requirement already satisfied: tqdm>4 in ./venv/lib/python3.9/site-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.14 in ./venv/lib/python3.9/site-packages (from openai) (4.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./venv/lib/python3.9/site-packages (from openai) (2.12.5)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./venv/lib/python3.9/site-packages (from openai) (0.28.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./venv/lib/python3.9/site-packages (from openai) (4.12.1)
# Requirement already satisfied: sniffio in ./venv/lib/python3.9/site-packages (from openai) (1.3.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in ./venv/lib/python3.9/site-packages (from openai) (0.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./venv/lib/python3.9/site-packages (from openai) (1.9.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./venv/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in ./venv/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: certifi in ./venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai) (2026.2.25)
# Requirement already satisfied: h11>=0.16 in ./venv/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./venv/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: pydantic-core==2.41.5 in ./venv/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# WARNING: You are using pip version 22.0.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/kpitsiakkos/Desktop/certificates/Langchain and Langgraph Specialization/venv/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install PyPDF
# Out:
# Requirement already satisfied: PyPDF in ./venv/lib/python3.9/site-packages (6.9.1)
# Requirement already satisfied: typing_extensions>=4.0 in ./venv/lib/python3.9/site-packages (from PyPDF) (4.15.0)
# WARNING: You are using pip version 22.0.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/kpitsiakkos/Desktop/certificates/Langchain and Langgraph Specialization/venv/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Using cached faiss_cpu-1.12.0.tar.gz (69 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting numpy<3.0,>=1.25.0
#   Using cached numpy-2.0.2-cp39-cp39-macosx_10_9_x86_64.whl (21.2 MB)
# Requirement already satisfied: packaging in ./venv/lib/python3.9/site-packages (from faiss-cpu) (25.0)
# Building wheels for collected packages: faiss-cpu
#   Building wheel for faiss-cpu (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for faiss-cpu (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [8 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       running build_ext
#       building 'faiss._swigfaiss' extension
#       swigging third-party/faiss/faiss/python/swigfaiss.i to third-party/faiss/faiss/python/swigfaiss_wrap.cpp
#       swig -python -c++ -Doverride= -doxygen -Ithird-party/faiss -I/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-5hbwge8q/overlay/lib/python3.9/site-packages/numpy/_core/include -Ithird-party/faiss -I/usr/local/include -o third-party/faiss/faiss/python/swigfaiss_wrap.cpp third-party/faiss/faiss/python/swigfaiss.i
#       error: command 'swig' failed: No such file or directory
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for faiss-cpu
# Failed to build faiss-cpu
# ERROR: Could not build wheels for faiss-cpu, which is required to install pyproject.toml-based projects
# WARNING: You are using pip version 22.0.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/kpitsiakkos/Desktop/certificates/Langchain and Langgraph Specialization/venv/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install tiktoken
# Out:
# Requirement already satisfied: tiktoken in ./venv/lib/python3.9/site-packages (0.12.0)
# Requirement already satisfied: requests>=2.26.0 in ./venv/lib/python3.9/site-packages (from tiktoken) (2.32.5)
# Requirement already satisfied: regex>=2022.1.18 in ./venv/lib/python3.9/site-packages (from tiktoken) (2026.1.15)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (2026.2.25)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (2.6.3)
# WARNING: You are using pip version 22.0.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/kpitsiakkos/Desktop/certificates/Langchain and Langgraph Specialization/venv/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.16.2-cp39-cp39-macosx_10_15_x86_64.whl (259.5 MB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3
#   Using cached protobuf-4.25.8-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting ml-dtypes~=0.3.1
#   Using cached ml_dtypes-0.3.2-cp39-cp39-macosx_10_9_universal2.whl (389 kB)
# Collecting libclang>=13.0.0
#   Using cached libclang-18.1.1-py2.py3-none-macosx_10_9_x86_64.whl (26.5 MB)
# Collecting keras>=3.0.0
#   Using cached keras-3.10.0-py3-none-any.whl (1.4 MB)
# Requirement already satisfied: packaging in ./venv/lib/python3.9/site-packages (from tensorflow) (25.0)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Collecting h5py>=3.10.0
#   Using cached h5py-3.14.0-cp39-cp39-macosx_10_9_x86_64.whl (3.3 MB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Using cached gast-0.7.0-py3-none-any.whl (22 kB)
# Collecting flatbuffers>=23.5.26
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Using cached tensorflow_io_gcs_filesystem-0.37.1-cp39-cp39-macosx_10_14_x86_64.whl (2.5 MB)
# Collecting wrapt>=1.11.0
#   Using cached wrapt-2.1.2-cp39-cp39-macosx_10_9_x86_64.whl (60 kB)
# Requirement already satisfied: setuptools in ./venv/lib/python3.9/site-packages (from tensorflow) (58.1.0)
# Collecting tensorboard<2.17,>=2.16
#   Using cached tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
# Requirement already satisfied: six>=1.12.0 in ./venv/lib/python3.9/site-packages (from tensorflow) (1.17.0)
# Collecting numpy<2.0.0,>=1.23.5
#   Using cached numpy-1.26.4-cp39-cp39-macosx_10_9_x86_64.whl (20.6 MB)
# Requirement already satisfied: requests<3,>=2.21.0 in ./venv/lib/python3.9/site-packages (from tensorflow) (2.32.5)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-2.3.1-py3-none-any.whl (135 kB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in ./venv/lib/python3.9/site-packages (from tensorflow) (4.15.0)
# Collecting grpcio<2.0,>=1.24.3
#   Using cached grpcio-1.78.0.tar.gz (12.9 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting wheel<1.0,>=0.23.0
#   Using cached wheel-0.46.3-py3-none-any.whl (30 kB)
# Collecting rich
#   Using cached rich-14.3.3-py3-none-any.whl (310 kB)
# Collecting optree
#   Using cached optree-0.19.0-cp39-cp39-macosx_10_9_x86_64.whl (392 kB)
# Collecting namex
#   Using cached namex-0.1.0-py3-none-any.whl (5.9 kB)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow) (2026.2.25)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.6)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Using cached tensorboard_data_server-0.7.2-py3-none-macosx_10_9_x86_64.whl (4.8 MB)
# Collecting markdown>=2.6.8
#   Using cached markdown-3.9-py3-none-any.whl (107 kB)
# Collecting werkzeug>=1.0.1
#   Using cached werkzeug-3.1.6-py3-none-any.whl (225 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in ./venv/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.17,>=2.16->tensorflow) (8.7.1)
# Collecting markupsafe>=2.1.1
#   Using cached markupsafe-3.0.3-cp39-cp39-macosx_10_9_x86_64.whl (11 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./venv/lib/python3.9/site-packages (from rich->keras>=3.0.0->tensorflow) (2.19.2)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Requirement already satisfied: zipp>=3.20 in ./venv/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.17,>=2.16->tensorflow) (3.23.0)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: grpcio
#   Building wheel for grpcio (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for grpcio (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [1905 lines of output]
#       SSE2 not enabled on macosx-10.9-x86_64 platform
#       Found cython-generated files...
#       running bdist_wheel
#       running build
#       running build_py
#       running build_project_metadata
#       creating pyb/lib.macosx-10.9-x86_64-cpython-39/grpc
#       copying src/python/grpcio/grpc/_typing.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc
#       copying src/python/grpcio/grpc/_compression.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc
#       copying src/python/grpcio/grpc/_channel.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc
#       copying src/python/grpcio/grpc/_common.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc
#       copying src/python/grpcio/grpc/__init__.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc
#       copying src/python/grpcio/grpc/_utilities.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc
#       copying src/python/grpcio/grpc/_simple_stubs.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc
#       copying src/python/grpcio/grpc/_observability.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc
#       copying src/python/grpcio/grpc/_plugin_wrapping.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc
#       copying src/python/grpcio/grpc/_interceptor.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc
#       copying src/python/grpcio/grpc/_grpcio_metadata.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc
#       copying src/python/grpcio/grpc/_server.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc
#       copying src/python/grpcio/grpc/_runtime_protos.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc
#       copying src/python/grpcio/grpc/_auth.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc
#       creating pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/beta
#       copying src/python/grpcio/grpc/beta/_server_adaptations.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/beta
#       copying src/python/grpcio/grpc/beta/interfaces.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/beta
#       copying src/python/grpcio/grpc/beta/_metadata.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/beta
#       copying src/python/grpcio/grpc/beta/__init__.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/beta
#       copying src/python/grpcio/grpc/beta/utilities.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/beta
#       copying src/python/grpcio/grpc/beta/implementations.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/beta
#       copying src/python/grpcio/grpc/beta/_client_adaptations.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/beta
#       creating pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/experimental
#       copying src/python/grpcio/grpc/experimental/gevent.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/experimental
#       copying src/python/grpcio/grpc/experimental/__init__.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/experimental
#       copying src/python/grpcio/grpc/experimental/session_cache.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/experimental
#       creating pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/framework
#       copying src/python/grpcio/grpc/framework/__init__.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/framework
#       creating pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/aio
#       copying src/python/grpcio/grpc/aio/_base_server.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/aio
#       copying src/python/grpcio/grpc/aio/_metadata.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/aio
#       copying src/python/grpcio/grpc/aio/_typing.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/aio
#       copying src/python/grpcio/grpc/aio/_call.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/aio
#       copying src/python/grpcio/grpc/aio/_channel.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/aio
#       copying src/python/grpcio/grpc/aio/__init__.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/aio
#       copying src/python/grpcio/grpc/aio/_base_channel.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/aio
#       copying src/python/grpcio/grpc/aio/_interceptor.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/aio
#       copying src/python/grpcio/grpc/aio/_server.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/aio
#       copying src/python/grpcio/grpc/aio/_base_call.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/aio
#       copying src/python/grpcio/grpc/aio/_utils.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/aio
#       creating pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/_cython
#       copying src/python/grpcio/grpc/_cython/__init__.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/_cython
#       creating pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/experimental/aio
#       copying src/python/grpcio/grpc/experimental/aio/__init__.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/experimental/aio
#       creating pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/framework/foundation
#       copying src/python/grpcio/grpc/framework/foundation/callable_util.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/framework/foundation
#       copying src/python/grpcio/grpc/framework/foundation/abandonment.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/framework/foundation
#       copying src/python/grpcio/grpc/framework/foundation/__init__.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/framework/foundation
#       copying src/python/grpcio/grpc/framework/foundation/stream.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/framework/foundation
#       copying src/python/grpcio/grpc/framework/foundation/stream_util.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/framework/foundation
#       copying src/python/grpcio/grpc/framework/foundation/future.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/framework/foundation
#       copying src/python/grpcio/grpc/framework/foundation/logging_pool.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/framework/foundation
#       creating pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/framework/common
#       copying src/python/grpcio/grpc/framework/common/style.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/framework/common
#       copying src/python/grpcio/grpc/framework/common/cardinality.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/framework/common
#       copying src/python/grpcio/grpc/framework/common/__init__.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/framework/common
#       creating pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/framework/interfaces
#       copying src/python/grpcio/grpc/framework/interfaces/__init__.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/framework/interfaces
#       creating pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/framework/interfaces/face
#       copying src/python/grpcio/grpc/framework/interfaces/face/__init__.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/framework/interfaces/face
#       copying src/python/grpcio/grpc/framework/interfaces/face/utilities.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/framework/interfaces/face
#       copying src/python/grpcio/grpc/framework/interfaces/face/face.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/framework/interfaces/face
#       creating pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/framework/interfaces/base
#       copying src/python/grpcio/grpc/framework/interfaces/base/__init__.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/framework/interfaces/base
#       copying src/python/grpcio/grpc/framework/interfaces/base/utilities.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/framework/interfaces/base
#       copying src/python/grpcio/grpc/framework/interfaces/base/base.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/framework/interfaces/base
#       creating pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/_cython/_cygrpc
#       copying src/python/grpcio/grpc/_cython/_cygrpc/__init__.py -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/_cython/_cygrpc
#       running egg_info
#       writing src/python/grpcio/grpcio.egg-info/PKG-INFO
#       writing dependency_links to src/python/grpcio/grpcio.egg-info/dependency_links.txt
#       writing requirements to src/python/grpcio/grpcio.egg-info/requires.txt
#       writing top-level names to src/python/grpcio/grpcio.egg-info/top_level.txt
#       reading manifest file 'src/python/grpcio/grpcio.egg-info/SOURCES.txt'
#       reading manifest template 'PYTHON-MANIFEST.in'
#       warning: no files found matching '*.c' under directory 'src/python/grpcio/grpc'
#       warning: no files found matching '*.h' under directory 'src/python/grpcio/grpc'
#       warning: no files found matching '*.inc' under directory 'src/python/grpcio/grpc'
#       warning: no files found matching '*.python' under directory 'src/python/grpcio/grpc'
#       warning: no previously-included files matching '*.so' found under directory 'src/python/grpcio/grpc/_cython'
#       warning: no previously-included files matching '*.pyd' found under directory 'src/python/grpcio/grpc/_cython'
#       warning: no files found matching 'src/python/grpcio/precompiled.py'
#       adding license file 'LICENSE'
#       writing manifest file 'src/python/grpcio/grpcio.egg-info/SOURCES.txt'
#       creating pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/_cython/_credentials
#       copying src/python/grpcio/grpc/_cython/_credentials/roots.pem -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/_cython/_credentials
#       copying src/python/grpcio/grpc/_cython/_credentials/roots.pem -> pyb/lib.macosx-10.9-x86_64-cpython-39/grpc/_cython/_credentials
#       running build_ext
#       Found cython-generated files...
#       building 'grpc._cython.cygrpc' extension
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/call
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/channelz
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/channelz/v2tov1
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/client_channel
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/config
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/credentials/call
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/credentials/call/composite
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/credentials/call/external
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/credentials/call/gcp_service_account_identity
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/credentials/call/iam
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/credentials/call/jwt
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/credentials/call/jwt_token_file
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/credentials/call/oauth2
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/credentials/call/plugin
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/credentials/call/token_fetcher
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/credentials/transport/alts
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/credentials/transport/composite
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/credentials/transport/fake
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/credentials/transport/google_default
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/credentials/transport/insecure
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/credentials/transport/local
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/credentials/transport/ssl
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/credentials/transport/tls
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/credentials/transport/xds
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/filters/backend_metrics
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/filters/census
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/filters/channel_idle
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/filters/fault_injection
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/filters/gcp_authentication
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/filters/http/client
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/filters/http/message_compress
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/filters/http/server
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/filters/message_size
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/filters/rbac
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/filters/stateful_session
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/transport/chttp2/alpn
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/transport/chttp2/client
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/transport/chttp2/server
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/transport/chttp2/transport
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/transport/inproc
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/admin/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/annotations
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/config/accesslog/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/config/bootstrap/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/config/cluster/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/config/common/matcher/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/config/core/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/config/endpoint/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/config/listener/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/config/metrics/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/config/overload/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/config/rbac/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/config/route/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/config/tap/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/config/trace/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/data/accesslog/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/extensions/clusters/aggregate/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/extensions/filters/common/fault/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/extensions/filters/http/fault/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/extensions/filters/http/gcp_authn/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/extensions/filters/http/rbac/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/extensions/filters/http/router/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/extensions/filters/http/stateful_session/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/extensions/filters/network/http_connection_manager/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/extensions/http/stateful_session/cookie/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/extensions/load_balancing_policies/client_side_weighted_round_robin/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/extensions/load_balancing_policies/common/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/extensions/load_balancing_policies/pick_first/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/extensions/load_balancing_policies/ring_hash/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/extensions/load_balancing_policies/wrr_locality/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/extensions/transport_sockets/http_11_proxy/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/extensions/transport_sockets/tls/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/extensions/upstreams/http/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/service/discovery/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/service/load_stats/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/service/status/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/type/http/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/type/matcher/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/type/metadata/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/type/tracing/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/envoy/type/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/google/api
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/google/api/expr/v1alpha1
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/google/protobuf
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/google/rpc
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/src/proto/grpc/channelz
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/src/proto/grpc/channelz/v2
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/src/proto/grpc/gcp
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/src/proto/grpc/health/v1
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/src/proto/grpc/lb/v1
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/src/proto/grpc/lookup/v1
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/udpa/annotations
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/validate
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/xds/annotations/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/xds/core/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/xds/data/orca/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/xds/service/orca/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/xds/type/matcher/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upb-gen/xds/type/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/admin/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/annotations
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/config/accesslog/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/config/bootstrap/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/config/cluster/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/config/common/matcher/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/config/core/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/config/endpoint/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/config/listener/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/config/metrics/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/config/overload/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/config/rbac/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/config/route/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/config/tap/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/config/trace/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/data/accesslog/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/extensions/clusters/aggregate/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/extensions/filters/common/fault/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/extensions/filters/http/fault/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/extensions/filters/http/gcp_authn/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/extensions/filters/http/rbac/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/extensions/filters/http/router/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/extensions/filters/http/stateful_session/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/extensions/filters/network/http_connection_manager/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/extensions/http/stateful_session/cookie/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/extensions/transport_sockets/http_11_proxy/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/extensions/transport_sockets/tls/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/extensions/upstreams/http/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/service/discovery/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/service/load_stats/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/service/status/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/type/http/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/type/matcher/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/type/metadata/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/type/tracing/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/envoy/type/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/google/api
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/google/api/expr/v1alpha1
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/google/protobuf
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/google/rpc
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/src/proto/grpc/channelz
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/src/proto/grpc/channelz/v2
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/src/proto/grpc/lookup/v1
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/udpa/annotations
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/validate
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/xds/annotations/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/xds/core/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/xds/type/matcher/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/ext/upbdefs-gen/xds/type/v3
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/filter/auth
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/handshaker/endpoint_info
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/handshaker/http_connect
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/handshaker/security
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/handshaker/tcp_connect
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/lib/address_utils
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/lib/channel
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/lib/compression
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/lib/debug
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/lib/event_engine
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/lib/event_engine/cf_engine
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/lib/event_engine/posix_engine
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/lib/event_engine/thread_pool
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/lib/event_engine/thready_event_engine
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/lib/event_engine/windows
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/lib/event_engine/work_queue
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/lib/experiments
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/lib/iomgr
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/lib/iomgr/event_engine_shims
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/lib/promise
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/lib/resource_quota
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/lib/resource_tracker
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/lib/security/authorization
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/lib/slice
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/lib/surface
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/lib/transport
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/load_balancing
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/load_balancing/grpclb
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/load_balancing/outlier_detection
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/load_balancing/pick_first
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/load_balancing/priority
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/load_balancing/ring_hash
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/load_balancing/rls
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/load_balancing/round_robin
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/load_balancing/weighted_round_robin
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/load_balancing/weighted_target
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/load_balancing/xds
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/net
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/plugin_registry
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/resolver/dns/c_ares
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/resolver/dns/event_engine
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/resolver/dns/native
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/resolver/fake
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/resolver/google_c2p
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/resolver/sockaddr
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/resolver/xds
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/server
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/service_config
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/telemetry
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/transport
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/tsi/alts/crypt
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/tsi/alts/frame_protector
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/tsi/alts/handshaker
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/tsi/alts/zero_copy_frame_protector
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/tsi/ssl/key_logging
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/tsi/ssl/session_cache
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/util
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/util/http_client
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/util/iphone
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/util/json
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/util/linux
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/util/msys
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/util/posix
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/util/windows
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/xds/grpc
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/xds/xds_client
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/src/python/grpcio/grpc/_cython
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/abseil-cpp/absl/base/internal
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/abseil-cpp/absl/container/internal
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/abseil-cpp/absl/crc
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/abseil-cpp/absl/crc/internal
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/abseil-cpp/absl/debugging/internal
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/abseil-cpp/absl/flags
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/abseil-cpp/absl/flags/internal
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/abseil-cpp/absl/hash/internal
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/abseil-cpp/absl/log
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/abseil-cpp/absl/log/internal
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/abseil-cpp/absl/numeric
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/abseil-cpp/absl/profiling/internal
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/abseil-cpp/absl/random
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/abseil-cpp/absl/random/internal
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/abseil-cpp/absl/status/internal
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/abseil-cpp/absl/strings
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/abseil-cpp/absl/strings/internal
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/abseil-cpp/absl/strings/internal/str_format
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/abseil-cpp/absl/synchronization
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/abseil-cpp/absl/synchronization/internal
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/abseil-cpp/absl/time
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/abseil-cpp/absl/time/internal/cctz/src
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/address_sorting
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/aes
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/asn1
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/base64
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/bio
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/blake2
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/bn
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/buf
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/bytestring
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/chacha
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/cipher
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/cms
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/conf
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/curve25519/asm
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/des
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/dh
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/digest
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/dsa
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/ec
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/ecdh
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/ecdsa
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/engine
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/err
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/evp
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/fipsmodule
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/hpke
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/hrss/asm
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/kyber
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/lhash
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/md4
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/md5
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/mldsa
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/mlkem
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/obj
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/pem
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/pkcs7
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/pkcs8
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/poly1305
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/pool
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/rand
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/rc4
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/rsa
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/sha
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/siphash
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/slhdsa
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/spake2plus
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/stack
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/trust_token
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/crypto/x509
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/gen/bcm
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/gen/crypto
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/gen/test_support
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/ssl
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/boringssl-with-bazel/src/third_party/fiat/asm
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/cares/cares/src/lib
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/cares/cares/src/lib/dsa
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/cares/cares/src/lib/event
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/cares/cares/src/lib/legacy
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/cares/cares/src/lib/record
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/cares/cares/src/lib/str
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/cares/cares/src/lib/util
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/re2/re2
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/re2/util
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/upb/upb/base
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/upb/upb/hash
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/upb/upb/json
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/upb/upb/lex
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/upb/upb/mem
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/upb/upb/message
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/upb/upb/message/internal
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/upb/upb/mini_descriptor
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/upb/upb/mini_descriptor/internal
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/upb/upb/mini_table
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/upb/upb/mini_table/internal
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/upb/upb/reflection
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/upb/upb/reflection/internal
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/upb/upb/text
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/upb/upb/text/internal
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/upb/upb/wire
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/upb/upb/wire/internal
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/utf8_range
#       creating pyb/temp.macosx-10.9-x86_64-cpython-39/third_party/zlib
#       clang++ -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/kpitsiakkos/opt/anaconda3/include -arch x86_64 -I/Users/kpitsiakkos/opt/anaconda3/include -fPIC -O2 -isystem /Users/kpitsiakkos/opt/anaconda3/include -arch x86_64 -D_WIN32_WINNT=1536 -DGRPC_XDS_USER_AGENT_NAME_SUFFIX=\"Python\" -DGRPC_XDS_USER_AGENT_VERSION_SUFFIX=\"1.78.0\" -DHAVE_CONFIG_H=1 -DGRPC_ENABLE_FORK_SUPPORT=1 -DGRPC_PYTHON_BUILD=1 -D__STDC_FORMAT_MACROS "-DPyMODINIT_FUNC=extern \"C\" __attribute__((visibility (\"default\"))) PyObject*" -DGRPC_POSIX_FORK_ALLOW_PTHREAD_ATFORK=1 -Isrc/python/grpcio -Iinclude -I. -Ithird_party/abseil-cpp -Ithird_party/address_sorting/include -Ithird_party/cares/cares/include -Ithird_party/cares -Ithird_party/cares/cares -Ithird_party/cares/cares/src/lib/include -Ithird_party/cares/cares/src/lib -Ithird_party/cares/config_darwin -Ithird_party/re2 -Ithird_party/boringssl-with-bazel/src/include -Ithird_party/upb -Isrc/core/ext/upb-gen -Isrc/core/ext/upbdefs-gen -Ithird_party/utf8_range -Ithird_party/xxhash -Ithird_party/zlib "-I/Users/kpitsiakkos/Desktop/certificates/Langchain and Langgraph Specialization/venv/include" -I/Users/kpitsiakkos/opt/anaconda3/include/python3.9 -c src/core/call/call_arena_allocator.cc -o pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/call/call_arena_allocator.o -std=c++17 -stdlib=libc++ -fvisibility=hidden -fno-wrapv -fno-exceptions -DHAVE_UNISTD_H -pthread
#       clang++ -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/kpitsiakkos/opt/anaconda3/include -arch x86_64 -I/Users/kpitsiakkos/opt/anaconda3/include -fPIC -O2 -isystem /Users/kpitsiakkos/opt/anaconda3/include -arch x86_64 -D_WIN32_WINNT=1536 -DGRPC_XDS_USER_AGENT_NAME_SUFFIX=\"Python\" -DGRPC_XDS_USER_AGENT_VERSION_SUFFIX=\"1.78.0\" -DHAVE_CONFIG_H=1 -DGRPC_ENABLE_FORK_SUPPORT=1 -DGRPC_PYTHON_BUILD=1 -D__STDC_FORMAT_MACROS "-DPyMODINIT_FUNC=extern \"C\" __attribute__((visibility (\"default\"))) PyObject*" -DGRPC_POSIX_FORK_ALLOW_PTHREAD_ATFORK=1 -Isrc/python/grpcio -Iinclude -I. -Ithird_party/abseil-cpp -Ithird_party/address_sorting/include -Ithird_party/cares/cares/include -Ithird_party/cares -Ithird_party/cares/cares -Ithird_party/cares/cares/src/lib/include -Ithird_party/cares/cares/src/lib -Ithird_party/cares/config_darwin -Ithird_party/re2 -Ithird_party/boringssl-with-bazel/src/include -Ithird_party/upb -Isrc/core/ext/upb-gen -Isrc/core/ext/upbdefs-gen -Ithird_party/utf8_range -Ithird_party/xxhash -Ithird_party/zlib "-I/Users/kpitsiakkos/Desktop/certificates/Langchain and Langgraph Specialization/venv/include" -I/Users/kpitsiakkos/opt/anaconda3/include/python3.9 -c src/core/credentials/call/external/aws_request_signer.cc -o pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/credentials/call/external/aws_request_signer.o -std=c++17 -stdlib=libc++ -fvisibility=hidden -fno-wrapv -fno-exceptions -DHAVE_UNISTD_H -pthread
# ...
#           build_ext.build_ext.build_extensions(self)
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/_distutils/command/build_ext.py", line 483, in build_extensions
#           self._build_extensions_serial()
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/_distutils/command/build_ext.py", line 509, in _build_extensions_serial
#           self.build_extension(ext)
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/command/build_ext.py", line 262, in build_extension
#           _build_ext.build_extension(self, ext)
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/Cython/Distutils/build_ext.py", line 136, in build_extension
#           super().build_extension(ext)
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/_distutils/command/build_ext.py", line 564, in build_extension
#           objects = self.compiler.compile(
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-install-vvutmceh/grpcio_9f5da6d7b2444d368ce16a5699e97509/src/python/grpcio/_parallel_compile_patch.py", line 70, in _parallel_compile
#           multiprocessing.pool.ThreadPool(BUILD_EXT_COMPILER_JOBS).map(
#         File "/Users/kpitsiakkos/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 364, in map
#           return self._map_async(func, iterable, mapstar, chunksize).get()
#         File "/Users/kpitsiakkos/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 771, in get
#           raise self._value
#         File "/Users/kpitsiakkos/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#           result = (True, func(*args, **kwds))
#         File "/Users/kpitsiakkos/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#           return list(map(*args))
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-install-vvutmceh/grpcio_9f5da6d7b2444d368ce16a5699e97509/src/python/grpcio/_parallel_compile_patch.py", line 65, in _compile_single_file
#           self._compile(obj, src, ext, cc_args, extra_postargs, pp_opts)
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-install-vvutmceh/grpcio_9f5da6d7b2444d368ce16a5699e97509/src/python/grpcio/commands.py", line 329, in new_compile
#           return old_compile(obj, src, ext, cc_args, extra_postargs, pp_opts)
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/_distutils/compilers/C/unix.py", line 223, in _compile
#           raise CompileError(msg)
#       distutils.compilers.C.errors.CompileError: command '/usr/bin/clang++' failed with exit code 1
#
#       During handling of the above exception, another exception occurred:
#
#       Traceback (most recent call last):
#         File "/Users/kpitsiakkos/Desktop/certificates/Langchain and Langgraph Specialization/venv/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 363, in <module>
#           main()
#         File "/Users/kpitsiakkos/Desktop/certificates/Langchain and Langgraph Specialization/venv/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 345, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#         File "/Users/kpitsiakkos/Desktop/certificates/Langchain and Langgraph Specialization/venv/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 261, in build_wheel
#           return _build_backend().build_wheel(wheel_directory, config_settings,
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/build_meta.py", line 441, in build_wheel
#           return _build(['bdist_wheel', '--dist-info-dir', str(metadata_directory)])
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/build_meta.py", line 429, in _build
#           return self._build_with_temp_dir(
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/build_meta.py", line 410, in _build_with_temp_dir
#           self.run_setup()
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/build_meta.py", line 317, in run_setup
#           exec(code, locals())
#         File "<string>", line 584, in <module>
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/__init__.py", line 117, in setup
#           return distutils.core.setup(**attrs)  # type: ignore[return-value]
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/_distutils/core.py", line 186, in setup
#           return run_commands(dist)
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/_distutils/core.py", line 202, in run_commands
#           dist.run_commands()
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/_distutils/dist.py", line 1000, in run_commands
#           self.run_command(cmd)
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/dist.py", line 1107, in run_command
#           super().run_command(command)
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/_distutils/dist.py", line 1019, in run_command
#           cmd_obj.run()
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/command/bdist_wheel.py", line 370, in run
#           self.run_command("build")
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/_distutils/cmd.py", line 341, in run_command
#           self.distribution.run_command(command)
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/dist.py", line 1107, in run_command
#           super().run_command(command)
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/_distutils/dist.py", line 1019, in run_command
#           cmd_obj.run()
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/_distutils/command/build.py", line 135, in run
#           self.run_command(cmd_name)
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/_distutils/cmd.py", line 341, in run_command
#           self.distribution.run_command(command)
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/dist.py", line 1107, in run_command
#           super().run_command(command)
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/_distutils/dist.py", line 1019, in run_command
#           cmd_obj.run()
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/command/build_ext.py", line 97, in run
#           _build_ext.run(self)
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/_distutils/command/build_ext.py", line 367, in run
#           self.build_extensions()
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-install-vvutmceh/grpcio_9f5da6d7b2444d368ce16a5699e97509/src/python/grpcio/commands.py", line 351, in build_extensions
#           raise CommandError(
#       commands.CommandError: Failed `build_ext` step:
#       Traceback (most recent call last):
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/_distutils/spawn.py", line 83, in spawn
#           subprocess.check_call(cmd, env=_inject_macos_ver(env))
#         File "/Users/kpitsiakkos/opt/anaconda3/lib/python3.9/subprocess.py", line 373, in check_call
#           raise CalledProcessError(retcode, cmd)
#       subprocess.CalledProcessError: Command '['/usr/bin/clang++', '-Wno-unused-result', '-Wsign-compare', '-Wunreachable-code', '-DNDEBUG', '-fwrapv', '-O2', '-Wall', '-fPIC', '-O2', '-isystem', '/Users/kpitsiakkos/opt/anaconda3/include', '-arch', 'x86_64', '-I/Users/kpitsiakkos/opt/anaconda3/include', '-fPIC', '-O2', '-isystem', '/Users/kpitsiakkos/opt/anaconda3/include', '-arch', 'x86_64', '-D_WIN32_WINNT=1536', '-DGRPC_XDS_USER_AGENT_NAME_SUFFIX="Python"', '-DGRPC_XDS_USER_AGENT_VERSION_SUFFIX="1.78.0"', '-DHAVE_CONFIG_H=1', '-DGRPC_ENABLE_FORK_SUPPORT=1', '-DGRPC_PYTHON_BUILD=1', '-D__STDC_FORMAT_MACROS', '-DPyMODINIT_FUNC=extern "C" __attribute__((visibility ("default"))) PyObject*', '-DGRPC_POSIX_FORK_ALLOW_PTHREAD_ATFORK=1', '-Isrc/python/grpcio', '-Iinclude', '-I.', '-Ithird_party/abseil-cpp', '-Ithird_party/address_sorting/include', '-Ithird_party/cares/cares/include', '-Ithird_party/cares', '-Ithird_party/cares/cares', '-Ithird_party/cares/cares/src/lib/include', '-Ithird_party/cares/cares/src/lib', '-Ithird_party/cares/config_darwin', '-Ithird_party/re2', '-Ithird_party/boringssl-with-bazel/src/include', '-Ithird_party/upb', '-Isrc/core/ext/upb-gen', '-Isrc/core/ext/upbdefs-gen', '-Ithird_party/utf8_range', '-Ithird_party/xxhash', '-Ithird_party/zlib', '-I/Users/kpitsiakkos/Desktop/certificates/Langchain and Langgraph Specialization/venv/include', '-I/Users/kpitsiakkos/opt/anaconda3/include/python3.9', '-c', 'src/core/credentials/call/external/aws_request_signer.cc', '-o', 'pyb/temp.macosx-10.9-x86_64-cpython-39/src/core/credentials/call/external/aws_request_signer.o', '-std=c++17', '-stdlib=libc++', '-fvisibility=hidden', '-fno-wrapv', '-fno-exceptions', '-DHAVE_UNISTD_H', '-pthread']' returned non-zero exit status 1.
#
#       The above exception was the direct cause of the following exception:
#
#       Traceback (most recent call last):
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/_distutils/compilers/C/unix.py", line 217, in _compile
#           self.spawn(
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-install-vvutmceh/grpcio_9f5da6d7b2444d368ce16a5699e97509/src/python/grpcio/_spawn_patch.py", line 66, in _commandfile_spawn
#           _classic_spawn(self, command, **kwargs)
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/_distutils/compilers/C/base.py", line 1151, in spawn
#           spawn(cmd, **kwargs)
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/_distutils/spawn.py", line 89, in spawn
#           raise DistutilsExecError(
#       distutils.errors.DistutilsExecError: command '/usr/bin/clang++' failed with exit code 1
#
#       During handling of the above exception, another exception occurred:
#
#       Traceback (most recent call last):
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-install-vvutmceh/grpcio_9f5da6d7b2444d368ce16a5699e97509/src/python/grpcio/commands.py", line 347, in build_extensions
#           build_ext.build_ext.build_extensions(self)
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/_distutils/command/build_ext.py", line 483, in build_extensions
#           self._build_extensions_serial()
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/_distutils/command/build_ext.py", line 509, in _build_extensions_serial
#           self.build_extension(ext)
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/command/build_ext.py", line 262, in build_extension
#           _build_ext.build_extension(self, ext)
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/Cython/Distutils/build_ext.py", line 136, in build_extension
#           super().build_extension(ext)
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/_distutils/command/build_ext.py", line 564, in build_extension
#           objects = self.compiler.compile(
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-install-vvutmceh/grpcio_9f5da6d7b2444d368ce16a5699e97509/src/python/grpcio/_parallel_compile_patch.py", line 70, in _parallel_compile
#           multiprocessing.pool.ThreadPool(BUILD_EXT_COMPILER_JOBS).map(
#         File "/Users/kpitsiakkos/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 364, in map
#           return self._map_async(func, iterable, mapstar, chunksize).get()
#         File "/Users/kpitsiakkos/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 771, in get
#           raise self._value
#         File "/Users/kpitsiakkos/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#           result = (True, func(*args, **kwds))
#         File "/Users/kpitsiakkos/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#           return list(map(*args))
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-install-vvutmceh/grpcio_9f5da6d7b2444d368ce16a5699e97509/src/python/grpcio/_parallel_compile_patch.py", line 65, in _compile_single_file
#           self._compile(obj, src, ext, cc_args, extra_postargs, pp_opts)
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-install-vvutmceh/grpcio_9f5da6d7b2444d368ce16a5699e97509/src/python/grpcio/commands.py", line 329, in new_compile
#           return old_compile(obj, src, ext, cc_args, extra_postargs, pp_opts)
#         File "/private/var/folders/tb/g1v2rhgn72b31g4hyg9skymh0000gn/T/pip-build-env-xvtl8ppw/overlay/lib/python3.9/site-packages/setuptools/_distutils/compilers/C/unix.py", line 223, in _compile
#           raise CompileError(msg)
#       distutils.compilers.C.errors.CompileError: command '/usr/bin/clang++' failed with exit code 1
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for grpcio
# Failed to build grpcio
# ERROR: Could not build wheels for grpcio, which is required to install pyproject.toml-based projects
# WARNING: You are using pip version 22.0.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/kpitsiakkos/Desktop/certificates/Langchain and Langgraph Specialization/venv/bin/python -m pip install --upgrade pip' command.
